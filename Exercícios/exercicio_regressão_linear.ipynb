# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, root_mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
df = pd.read_csv('new_cars.csv')

# %%
df
# Out:
#      Unnamed: 0   mpg  cylinders  displacement  horsepower  weight  \
# 0             0  18.0          8         307.0       130.0    3504
# 1             1  15.0          8         350.0       165.0    3693
# 2             2  18.0          8         318.0       150.0    3436
# 3             3  16.0          8         304.0       150.0    3433
# 4             4  17.0          8         302.0       140.0    3449
# ..          ...   ...        ...           ...         ...     ...
# 393         393  27.0          4         140.0        86.0    2790
# 394         394  44.0          4          97.0        52.0    2130
# 395         395  32.0          4         135.0        84.0    2295
# 396         396  28.0          4         120.0        79.0    2625
# 397         397  31.0          4         119.0        82.0    2720
#
#      acceleration  model year  origin_asia  origin_europa
# 0            12.0          70            0              0
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0         mpg   cylinders  displacement  horsepower  \
# count  398.000000  398.000000  398.000000    398.000000  398.000000
# mean   198.500000   23.514573    5.454774    193.425879  104.304020
# std    115.036951    7.815984    1.701004    104.269838   38.222625
# min      0.000000    9.000000    3.000000     68.000000   46.000000
# 25%     99.250000   17.500000    4.000000    104.250000   76.000000
# 50%    198.500000   23.000000    4.000000    148.500000   93.500000
# 75%    297.750000   29.000000    8.000000    262.000000  125.000000
# max    397.000000   46.600000    8.000000    455.000000  230.000000
#
#             weight  acceleration  model year  origin_asia  origin_europa
# count   398.000000    398.000000  398.000000   398.000000     398.000000
# mean   2970.424623     15.568090   76.010050     0.198492       0.175879
# std     846.841774      2.757689    3.697627     0.399367       0.381197
# ...

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
y = df['mpg']
X = df.drop(['mpg'], axis=1)

# %%
X_treino, X_teste, y_treino, y_teste = train_test_split(X, y, train_size=0.7, random_state=42)

# %%
LR = LinearRegression()

# %%
LR.fit(X_treino, y_treino)
# Out:
# LinearRegression()

# %%
predictions = LR.predict(X_teste)

# %%
mae = mean_absolute_error(y_true=y_teste, y_pred=predictions)
mse = mean_squared_error(y_true=y_teste, y_pred=predictions)
rmse = root_mean_squared_error(y_true=y_teste, y_pred=predictions)
r2 = r2_score(y_true=y_teste, y_pred=predictions)

# %%
print('LinearRegression()')
print('MAE: ', mae)
print('MSE: ', mse)
print('RMSE: ', rmse)
print('R2: ', r2)
# Out:
# LinearRegression()
# MAE:  2.3845254245585275
# MSE:  9.051070930002362
# RMSE:  3.008499780621957
# R2:  0.8422921095319243
