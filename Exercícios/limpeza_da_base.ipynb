# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('diabetes.csv')

# %%
import scipy

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df['Pregnancies'].unique()
# Out:
# array([ 6,  1,  8,  0,  5,  3, 10,  2,  4,  7,  9, 11, 13, 15, 17, 12, 14])

# %%
df.nunique()
# Out:
# Pregnancies                  17
# Glucose                     136
# BloodPressure                47
# SkinThickness                51
# Insulin                     186
# BMI                         248
# DiabetesPedigreeFunction    517
# Age                          52
# Outcome                       2
# dtype: int64

# %%
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:>

# %%
df.isnull()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0          False    False          False          False    False  False
# 1          False    False          False          False    False  False
# 2          False    False          False          False    False  False
# 3          False    False          False          False    False  False
# 4          False    False          False          False    False  False
# ..           ...      ...            ...            ...      ...    ...
# 763        False    False          False          False    False  False
# 764        False    False          False          False    False  False
# 765        False    False          False          False    False  False
# 766        False    False          False          False    False  False
# 767        False    False          False          False    False  False
#
#      DiabetesPedigreeFunction    Age  Outcome
# 0                       False  False    False
# ...

# %%
df.describe().T
# Out:
#                           count        mean         std     min       25%  \
# Pregnancies               768.0    3.845052    3.369578   0.000   1.00000
# Glucose                   768.0  120.894531   31.972618   0.000  99.00000
# BloodPressure             768.0   69.105469   19.355807   0.000  62.00000
# SkinThickness             768.0   20.536458   15.952218   0.000   0.00000
# Insulin                   768.0   79.799479  115.244002   0.000   0.00000
# BMI                       768.0   31.992578    7.884160   0.000  27.30000
# DiabetesPedigreeFunction  768.0    0.471876    0.331329   0.078   0.24375
# Age                       768.0   33.240885   11.760232  21.000  24.00000
# Outcome                   768.0    0.348958    0.476951   0.000   0.00000
#
#                                50%        75%     max
# Pregnancies                 3.0000    6.00000   17.00
# Glucose                   117.0000  140.25000  199.00
# BloodPressure              72.0000   80.00000  122.00
# ...

# %%
sns.boxplot(df)
# Out:
# <AxesSubplot:>

# %%
Q1, Q3 = np.percentile(df['Pregnancies'], [25, 75])

# %%
Q1
# Out:
# 1.0

# %%
Q3
# Out:
# 6.0

# %%
#intervalo interquartil
IRQ = Q3 - Q1

# %%
limite_inferior = Q1 - (1.5 * IRQ)
limite_superior = Q3 + (1.5 * IRQ)

# %%
limite_inferior
# Out:
# -6.5

# %%
limite_superior
# Out:
# 13.5

# %%
df_limpo = df[(df['Pregnancies']>= limite_inferior) & (df['Pregnancies']<=limite_superior)]

# %%
sns
# Out:
# <module 'seaborn' from '/home/gvieira/.local/lib/python3.10/site-packages/seaborn/__init__.py'>

# %%
Q1, Q3 = np.percentile(df['Insulin'], [25, 75])
IRQ = Q3 - Q1
limite_inferior = Q1 - (1.5 * IRQ)
limite_superior = Q3 + (1.5 * IRQ)
df_limpo = df_limpo[(df_limpo['Insulin']>= limite_inferior) & (df_limpo['Insulin']<=limite_superior)]

# %%
Q1, Q3 = np.percentile(df['Age'], [25, 75])
IRQ = Q3 - Q1
limite_inferior = Q1 - (1.5 * IRQ)
limite_superior = Q3 + (1.5 * IRQ)
df_limpo = df_limpo[(df_limpo['Age']>= limite_inferior) & (df_limpo['Age']<=limite_superior)]

# %%
Q1, Q3 = np.percentile(df['Glucose'], [25, 75])
IRQ = Q3 - Q1
limite_inferior = Q1 - (1.5 * IRQ)
limite_superior = Q3 + (1.5 * IRQ)
df_limpo = df_limpo[(df_limpo['Glucose']>= limite_inferior) & (df_limpo['Glucose']<=limite_superior)]

# %%
Q1, Q3 = np.percentile(df['BloodPressure'], [25, 75])
IRQ = Q3 - Q1
limite_inferior = Q1 - (1.5 * IRQ)
limite_superior = Q3 + (1.5 * IRQ)
df_limpo = df_limpo[(df_limpo['BloodPressure']>= limite_inferior) & (df_limpo['BloodPressure']<=limite_superior)]

# %%
Q1, Q3 = np.percentile(df['SkinThickness'], [25, 75])
IRQ = Q3 - Q1
limite_inferior = Q1 - (1.5 * IRQ)
limite_superior = Q3 + (1.5 * IRQ)
df_limpo = df_limpo[(df_limpo['SkinThickness']>= limite_inferior) & (df_limpo['SkinThickness']<=limite_superior)]

# %%
correlacao = df.corr()
correlacao
#covariancia de dois elementos, quanto um varia em relação ao outro
# Out:
#                           Pregnancies   Glucose  BloodPressure  SkinThickness  \
# Pregnancies                  1.000000  0.129459       0.141282      -0.081672
# Glucose                      0.129459  1.000000       0.152590       0.057328
# BloodPressure                0.141282  0.152590       1.000000       0.207371
# SkinThickness               -0.081672  0.057328       0.207371       1.000000
# Insulin                     -0.073535  0.331357       0.088933       0.436783
# BMI                          0.017683  0.221071       0.281805       0.392573
# DiabetesPedigreeFunction    -0.033523  0.137337       0.041265       0.183928
# Age                          0.544341  0.263514       0.239528      -0.113970
# Outcome                      0.221898  0.466581       0.065068       0.074752
#
#                            Insulin       BMI  DiabetesPedigreeFunction  \
# Pregnancies              -0.073535  0.017683                 -0.033523
# ...

# %%
#negativa= a é crescente, b é crescente

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %%
#MAIS UMA VARIAVEL VARIA JUNTO COM A OUTRA
#AGE CRESCE, PREGNANCIES CRESCE TBM

# %%
correlacao['Age'].sort_values(ascending=False)
# Out:
# Age                         1.000000
# Pregnancies                 0.544341
# Glucose                     0.263514
# BloodPressure               0.239528
# Outcome                     0.238356
# BMI                         0.036242
# DiabetesPedigreeFunction    0.033561
# Insulin                    -0.042163
# SkinThickness              -0.113970
# Name: Age, dtype: float64

# %%
plt.pie(df.Outcome.value_counts())
# Out:
# ([<matplotlib.patches.Wedge at 0x7350ddce3dc0>,
# ...
#  [Text(-0.5025943242672991, 0.9784676515931925, ''),
#   Text(0.5025944158780503, -0.9784676045369114, '')])

# %%
sns.pairplot(df_limpo, hue='Outcome')

# %%
from sklearn.preprocessing import MinMaxScaler
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /tmp/ipykernel_3034/1724117808.py in <module>
# ----> 1 from sklearn.preprocessing import MinMaxScaler
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
escala = MinMaxScaler()

# %%
x = df.drop(columns=['Outcome'])
y = df.Outcome

# %%
escala.fit(x)
Xescalar = escala.fit_transform(x)

# %%
Xescalar

# %%
# Média 0 e desvio padrão 1

# %%
df.describe().T

# %%
df_titanic = pd.read_csv('titanic.csv')

# %%
df_titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
df_titanic.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 886     True
# 887    False
# 888    False
# 889    False
# 890    False
# Length: 891, dtype: bool

# %%
df_titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    object
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    object
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), float64(2), int64(4), object(7)
# memory usage: 92.4+ KB

# %%
cat_col = [col for col in df_titanic.columns if df_titanic[col].dtype == 'object']
print(cat_col)
# Out:
# ['sex', 'embarked', 'class', 'who', 'deck', 'embark_town', 'alive']

# %%
num_col = [col for col in df_titanic.columns if df_titanic[col].dtype != 'object']
print(num_col)
# Out:
# ['survived', 'pclass', 'age', 'sibsp', 'parch', 'fare', 'adult_male', 'alone']

# %%
df_titanic[cat_col].nunique()
# Out:
# sex            2
# embarked       3
# class          3
# who            3
# deck           7
# embark_town    3
# alive          2
# dtype: int64

# %%
df_titanic['deck'].unique()[:50]
# Out:
# array([nan, 'C', 'E', 'G', 'D', 'A', 'B', 'F'], dtype=object)

# %%
df_titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
177/890
# Out:
# 0.19887640449438201

# %%
2/890
# Out:
# 0.0022471910112359553

# %%
df_titanic_2 = df_titanic.drop(columns='deck')
df_titanic_2.dropna(subset=['embark_town'], axis=0, inplace=True)

# %%
df_titanic_2.shape
# Out:
# (889, 14)

# %%
df_titanic.shape
# Out:
# (891, 15)

# %%
sns.boxplot(data=df_titanic_2, x='pclass', y='age')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='age'>

# %%
#olhando o valor da mediana
#tirar 177 elementos do age

# %%
df_titanic['age'].mean()
# Out:
# 29.69911764705882

# %%
df_titanic['age'].max()
# Out:
# 80.0

# %%
df_titanic['age'].min()
# Out:
# 0.42

# %%
df_titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
688/890
# Out:
# 0.7730337078651686

# %%
sns.countplot(data=df_titanic_2, x='pclass')
# Out:
# <AxesSubplot:xlabel='pclass', ylabel='count'>

# %%
sns.histplot(data=df_titanic_2, x='age', kde=True)
# Out:
# <AxesSubplot:xlabel='age', ylabel='Count'>

# %%
df_titanic['age'].median()
# Out:
# 28.0

# %%
mediana_c1 = df_titanic['age'].median() if df_titanic['pclass'] == 1
# Out:
#   File "/tmp/ipykernel_3034/2642875616.py", line 1
#     mediana_c1 = df_titanic['age'].median() if df_titanic['pclass'] == 1
#                  ^
# SyntaxError: expected 'else' after 'if' expression

# %%
mediana_c1 = df_titanic_2[df_titanic_2['pclass'] == 1]['age'].median()
mediana_c2 = df_titanic_2[df_titanic_2['pclass'] == 2]['age'].median()
mediana_c3 = df_titanic_2[df_titanic_2['pclass'] == 3]['age'].median()

# %%
print(mediana_c1)
print(mediana_c2)
print(mediana_c3)
# Out:
# 37.0
# 29.0
# 24.0

# %%
media_c1 = df_titanic_2[df_titanic_2['pclass'] == 1]['age'].mean()
media_c2 = df_titanic_2[df_titanic_2['pclass'] == 2]['age'].mean()
media_c3 = df_titanic_2[df_titanic_2['pclass'] == 3]['age'].mean()

# %%
print(media_c1)
print(media_c2)
print(media_c3)
# Out:
# 38.10554347826087
# 29.87763005780347
# 25.14061971830986

# %%
max_c1 = df_titanic_2[df_titanic_2['pclass'] == 1]['age'].max()
max_c2 = df_titanic_2[df_titanic_2['pclass'] == 2]['age'].max()
max_c3 = df_titanic_2[df_titanic_2['pclass'] == 3]['age'].max()
print(max_c1)
print(max_c2)
print(max_c3)
# Out:
# 80.0
# 70.0
# 74.0

# %%
mediana_c1 = df_titanic_2[df_titanic_2['pclass'] == 1]['age'].median()
mediana_c2 = df_titanic_2[df_titanic_2['pclass'] == 2]['age'].median()
mediana_c3 = df_titanic_2[df_titanic_2['pclass'] == 3]['age'].median()
print(mediana_c1)
print(mediana_c2)
print(mediana_c3)
# Out:
# 37.0
# 29.0
# 24.0

# %%
for idade in df_titanic_2['age']:
    if (df_titanic_2['pclass'] == 1 and df_titanic_2['age'].isnull() == True):
        df_titanic_2['age'].idade == mediana_c1
    elif (df_titanic_2['pclass'] == 2 and df_titanic_2['age'].isnull() == True):
        df_titanic_2['age'].idade == mediana_c2
    elif (df_titanic_2['pclass'] == 3 and df_titanic_2['age'].isnull() == True):
        df_titanic_2['age'].idade == mediana_c3
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3034/2303944620.py in <module>
#       1 for idade in df_titanic_2['age']:
# ----> 2     if (df_titanic_2['pclass'] == 1 and df_titanic_2['age'].isnull() == True):
#       3         df_titanic_2['age'].idade == mediana_c1
#       4     elif (df_titanic_2['pclass'] == 2 and df_titanic_2['age'].isnull() == True):
#       5         df_titanic_2['age'].idade == mediana_c2
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
df_titanic_2.loc[(df_titanic_2['pclass'] == 1) & (df_titanic_2['age'].isnull()), 'age'] = mediana_c1
df_titanic_2.loc[(df_titanic_2['pclass'] == 2) & (df_titanic_2['age'].isnull()), 'age'] = mediana_c2
df_titanic_2.loc[(df_titanic_2['pclass'] == 3) & (df_titanic_2['age'].isnull()), 'age'] = mediana_c3

# %%
df_titanic_3.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df_titanic_2['age'].head(20)
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5     24.0
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
# 15    55.0
# 16     2.0
# 17    29.0
# 18    31.0
# 19    24.0
# Name: age, dtype: float64

# %%
df_titanic_3 = df_titanic

# %%
df_titanic_2.loc[(df_titanic_2['pclass'] == 1) & (df_titanic_2['age'].isnull()), 'age'] = mediana_c1
df_titanic_2.loc[(df_titanic_2['pclass'] == 2) & (df_titanic_2['age'].isnull()), 'age'] = mediana_c2
df_titanic_2.loc[(df_titanic_2['pclass'] == 3) & (df_titanic_2['age'].isnull()), 'age'] = mediana_c3


for idade in df_titanic['age']:
    if (df_titanic.loc[(df_titanic['pclass'] == 1) & (df_titanic['age'].isnull())]):
        df_titanic['age'] = mediana_c1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3034/3916955623.py in <module>
#       5
#       6 for idade in df_titanic['age']:
# ----> 7     if (df_titanic.loc[(df_titanic['pclass'] == 1) & (df_titanic['age'].isnull())]):
#       8         df_titanic['age'] = mediana_c1
#
# /usr/lib/python3/dist-packages/pandas/core/generic.py in __nonzero__(self)
#    1535     @final
#    1536     def __nonzero__(self):
# -> 1537         raise ValueError(
#    1538             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1539             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#
# ValueError: The truth value of a DataFrame is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
for index, row in df_titanic.iterrows():
    if row['pclass'] == 1 and pd.isnull(row['age']):
        df_titanic.at[index, 'age'] = mediana_c1
    elif row['pclass'] == 2 and pd.isnull(row['age']):
        df_titanic.at[index, 'age'] = mediana_c2
    elif row['pclass'] == 3 and pd.isnull(row['age']):
        df_titanic.at[index, 'age'] = mediana_c3

# %%
df_titanic.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age              0
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# deck           688
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df_titanic['age'].head(20)
# Out:
# 0     22.0
# 1     38.0
# 2     26.0
# 3     35.0
# 4     35.0
# 5     24.0
# 6     54.0
# 7      2.0
# 8     27.0
# 9     14.0
# 10     4.0
# 11    58.0
# 12    20.0
# 13    39.0
# 14    14.0
# 15    55.0
# 16     2.0
# 17    29.0
# 18    31.0
# 19    24.0
# Name: age, dtype: float64
